# %% [markdown]
# # 0.0 Imports

# %%
import pandas            as pd
import numpy             as np
import seaborn           as sns
import sweetviz          as sv
import xgboost           as xgb
import inflection

from matplotlib              import pyplot   as plt
from scipy                   import stats    as ss
from sklearn                 import ensemble as en
from boruta                  import BorutaPy
from IPython.core.display    import HTML
from IPython.display         import Image
from sklearn.preprocessing   import MinMaxScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics         import mean_absolute_error
from sklearn.metrics         import mean_squared_error
from sklearn.metrics         import mean_absolute_percentage_error
from sklearn.metrics         import accuracy_score
from sklearn.metrics         import f1_score
from sklearn.linear_model    import LinearRegression, Lasso, LogisticRegression
from sklearn.ensemble        import RandomForestClassifier
from sklearn.datasets        import make_classification

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline

    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    
def cramer_v(x, y):
    cm = pd.crosstab(x, y).to_numpy()
    n = cm.sum()
    r, k = cm.shape
    
    chi2 = ss.chi2_contingency(cm)[0]
    chi2corr = max(0, chi2 - (k - 1)*(r - 1) / (n - 1))
    
    kcorr = k - (k - 1)**2 / (n - 1)
    rcorr = r - (k - 1)**2 / (n - 1)
    
    return np.sqrt((chi2corr / n) / (min(kcorr - 1, rcorr - 1)))

def ml_error( model_name, y, yhat ):
    mae = mean_absolute_error( y, yhat )
    mape = mean_absolute_percentage_error( y, yhat )
    rmse = np.sqrt( mean_squared_error( y, yhat ) )
    
    return pd.DataFrame( { 'Model Name': model_name,
                            'MAE': mae,
                            'MAPE': mape,
                            'RMSE': rmse }, index=[0] )

def cross_validation(x_training, kfold, model_name, model, verbose = False):

    # Lists to store results
    mae_list = []
    mape_list = []
    rmse_list = []

    for k in reversed(range(1, kfold+1)):
        
        # Verbose Mode
        if verbose:
            print(f'Kfold Number: {k}')
            
        # start and end for validation
        validation_start_date = x_training.max() - datetime.timedelta(days=k*6*7)
        validation_end_date = x_training.max() - datetime.timedelta(days=(k-1)*6*7)

        # filtering dataset
        training = x_training[x_training < validation_start_date]
        validation = x_training[(x_training['date'] >= validation_start_date) & (x_training['date'] <= validation_end_date)]

        # training and validation Dataset
        # training
        xtraining = training.drop(['date', 'sales'], axis=1)
        ytraining = training['sales']

        # validation
        xvalidation = validation.drop(['date', 'sales'], axis=1)
        yvalidation = validation['sales']

        # model
        
        m = model.fit(xtraining, ytraining)

        # prediction
        yhat = m.predict(xvalidation)

        # performance
        m_result = ml_error('Linear Regression', np.expm1(yvalidation), np.expm1(yhat))

        # store performance for each kfold iteration
        mae_list.append(m_result['MAE'])
        mape_list.append(m_result['MAPE'])
        rmse_list.append(m_result['RMSE'])

    return pd.DataFrame({
        'Model Name': model_name,
        'MAE CV': np.round(np.mean(mae_list), 2).astype(str) + ' +/- ' + np.round(np.std(mae_list), 2).astype(str),
        'MAPE CV': np.round(np.mean(mape_list), 2).astype(str) + ' +/- ' + np.round(np.std(mape_list), 2).astype(str),
        'RMSE CV': np.round(np.mean(rmse_list), 2).astype(str) + ' +/- ' + np.round(np.std(rmse_list), 2).astype(str)
    }, index=[0])

# %%
jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## 0.2 Loading Data

# %%
df_raw = pd.read_csv('../data/raw/churn.csv', low_memory=False)

# %%
df_raw.sample()
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 8240       8241    15708504    Wong          790   Germany   Male   50       8  121438.58              1          1               1        176471.78       1

# %% [markdown]
# # 1.0 Data Description

# %%
# Cópia para otimização
df1 = df_raw.copy()

# %% [markdown]
# ## 1.1 Rename Columns

# %%
old_cols = ['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
       'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
       'IsActiveMember', 'EstimatedSalary', 'Exited']

snake_case = lambda x: inflection.underscore(x)

new_cols = list( map(snake_case, old_cols))
df1.columns = new_cols

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
print("Number of rows: {}".format(df1.shape[0]))
print("Number of columns: {}".format(df1.shape[1]))
# Out:
# Number of rows: 10000
# Number of columns: 14

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# row_number            int64
# customer_id           int64
# surname              object
# credit_score          int64
# geography            object
# gender               object
# age                   int64
# tenure                int64
# balance             float64
# num_of_products       int64
# has_cr_card           int64
# is_active_member      int64
# estimated_salary    float64
# exited                int64
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# row_number          0
# customer_id         0
# surname             0
# credit_score        0
# geography           0
# gender              0
# age                 0
# tenure              0
# balance             0
# num_of_products     0
# has_cr_card         0
# is_active_member    0
# estimated_salary    0
# exited              0
# dtype: int64

# %% [markdown]
# ## 1.5 Fillout NA

# %%
# There's no NA data in this dataset

# %% [markdown]
# ## 1.6 Change Types

# %%
# There's no data to change in this dataset

# %% [markdown]
# ## 1.7 Descriptive Statistical

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'])
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64'])

# %% [markdown]
# ### 1.7.1 Numerical Attributes

# %%
# Central tendency - mean, median
ct1 = pd.DataFrame(num_attributes.apply(np.mean)).T
ct2 = pd.DataFrame(num_attributes.apply(np.median)).T

# Dispersion - std, max, min, range, skew, kurtosis
d1 = pd.DataFrame(num_attributes.apply(np.std)).T
d2 = pd.DataFrame(num_attributes.apply(min)).T
d3 = pd.DataFrame(num_attributes.apply(max)).T
d4 = pd.DataFrame(num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame(num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame(num_attributes.apply(lambda x: x.kurtosis())).T

# Concatenate
m = pd.concat([d2, d3, d4, ct1, ct2, d1, d5, d6]).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#           attributes          min          max      range          mean        median           std      skew  kurtosis
# 0         row_number         1.00     10000.00    9999.00  5.000500e+03  5.000500e+03   2886.751332  0.000000 -1.200000
# 1        customer_id  15565701.00  15815690.00  249989.00  1.569094e+07  1.569074e+07  71932.589224  0.001149 -1.196113
# 2       credit_score       350.00       850.00     500.00  6.505288e+02  6.520000e+02     96.648466 -0.071607 -0.425726
# 3                age        18.00        92.00      74.00  3.892180e+01  3.700000e+01     10.487282  1.011320  1.395347
# 4             tenure         0.00        10.00      10.00  5.012800e+00  5.000000e+00      2.892030  0.010991 -1.165225
# 5            balance         0.00    250898.09  250898.09  7.648589e+04  9.719854e+04  62394.285254 -0.141109 -1.489412
# 6    num_of_products         1.00         4.00       3.00  1.530200e+00  1.000000e+00      0.581625  0.745568  0.582981
# 7        has_cr_card         0.00         1.00       1.00  7.055000e-01  1.000000e+00      0.455818 -0.901812 -1.186973
# 8   is_active_member         0.00         1.00       1.00  5.151000e-01  1.000000e+00      0.499772 -0.060437 -1.996747
# 9   estimated_salary        11.58    199992.48  199980.90  1.000902e+05  1.001939e+05  57507.617221  0.002085 -1.181518
# 10            exited         0.00         1.00       1.00  2.037000e-01  0.000000e+00      0.402748  1.471611  0.165671

# %%
# Análise das variáveis numéricas no boxplot
plt.figure(figsize=(15,10))

plt.subplot(2, 3, 1)
sns.boxplot(x='credit_score', data=num_attributes)

plt.subplot(2, 3, 2)
sns.boxplot(x='age', data=num_attributes)

plt.subplot(2, 3, 3)
sns.boxplot(x='tenure', data=num_attributes)

plt.subplot(2, 3, 4)
sns.boxplot(x='balance', data=num_attributes)

plt.subplot(2, 3, 5)
sns.boxplot(x='num_of_products', data=num_attributes)

plt.subplot(2, 3, 6)
sns.boxplot(x='estimated_salary', data=num_attributes)
# Out:
# <AxesSubplot:xlabel='estimated_salary'>

# %% [markdown]
# ### 1.7.2 Categorical Attributes

# %%
# Quantas variáveis categóricas em cada feature
cat_attributes.apply( lambda x: x.unique().shape[0] )
# Out:
# surname      2932
# geography       3
# gender          2
# dtype: int64

# %%
# Quais variáveis
cat_attributes.apply( lambda x: x.unique() )
# Out:
# surname      [Hargrave, Hill, Onio, Boni, Mitchell, Chu, Ba...
# geography                             [France, Spain, Germany]
# gender                                          [Female, Male]
# dtype: object

# %% [markdown]
# # 2.0 Feature Engineering

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 MindMap Hypothesis

# %% [markdown]
# ## 2.2 Creating Hypothesis

# %% [markdown]
# ### 2.2.1 Hipóteses Características Pessoais

# %%
1.A atividade do cliente influencia em possível churn?
2.A localidade do cliente influencia em possível churn?
3.A idade do cliente influencia em possível churn?
4.O gênero do cliente influencia em possível churn?
5.A tenure do cliente influencia em possível churn?
6.O fato do cliente possuir cartão de crédito influencia em possível churn?
# Out:
# Object `churn` not found.
# Object `churn` not found.
# Object `churn` not found.
# Object `churn` not found.
# Object `churn` not found.
# Object `churn` not found.

# %% [markdown]
# ### 2.2.2 Hipóteses Características Financeiras

# %%
1.O salário do cliente influencia em possível churn?
2.O score do cliente influencia em possível churn?
3.O número de produtos comprados pelo cliente influencia em possível churn?
4.O balanço financeiro do cliente influencia em possível churn?
# Out:
# Object `churn` not found.
# Object `churn` not found.
# Object `churn` not found.
# Object `churn` not found.

# %% [markdown]
# ## 2.3 Final List of Hypothesis

# %%
1.A atividade do cliente influencia em possível churn?
2.A localidade do cliente influencia em possível churn?
3.A idade do cliente influencia em possível churn?
4.O gênero do cliente influencia em possível churn?
5.A tenure do cliente influencia em possível churn?
6.O fato do cliente possuir cartão de crédito influencia em possível churn?
7.O salário do cliente influencia em possível churn?
8.O score do cliente influencia em possível churn?
9.O número de produtos comprados pelo cliente influencia em possível churn?
10.O balanço financeiro do cliente influencia em possível churn?

# %% [markdown]
# ## 2.4 Feature Engineering

# %% [markdown]
# # 3.0 Filtragem de Variáveis

# %%
df3 = df2.copy()

# %%
df3.head()
# Out:
#    row_number  customer_id   surname  credit_score geography  gender  age  tenure    balance  num_of_products  has_cr_card  is_active_member  estimated_salary  exited
# 0           1     15634602  Hargrave           619    France  Female   42       2       0.00                1            1                 1         101348.88       1
# 1           2     15647311      Hill           608     Spain  Female   41       1   83807.86                1            0                 1         112542.58       0
# 2           3     15619304      Onio           502    France  Female   42       8  159660.80                3            1                 0         113931.57       1
# 3           4     15701354      Boni           699    France  Female   39       1       0.00                2            0                 0          93826.63       0
# 4           5     15737888  Mitchell           850     Spain  Female   43       2  125510.82                1            1                 1          79084.10       0

# %% [markdown]
# ## 3.1 Filtragem de linhas

# %% [markdown]
# ## 3.2 Filtragem de colunas

# %%
cols_drop = ['row_number', 'customer_id', 'surname']

df3 = df3.drop(cols_drop, axis=1)

# %% [markdown]
# # 4.0 Análise Exploratória de Dados

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Análise Univariada

# %% [markdown]
# ### 4.1.1 Response Variable

# %%
sns.distplot(df4['exited'])
# Out:
# /Users/luishmq/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='exited', ylabel='Density'>

# %% [markdown]
# ### 4.1.2 Numerical Variable

# %%
num_attributes.hist(bins=25)
# Out:
# array([[<AxesSubplot:title={'center':'row_number'}>,
#         <AxesSubplot:title={'center':'customer_id'}>,
#         <AxesSubplot:title={'center':'credit_score'}>],
#        [<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'tenure'}>,
#         <AxesSubplot:title={'center':'balance'}>],
#        [<AxesSubplot:title={'center':'num_of_products'}>,
#         <AxesSubplot:title={'center':'has_cr_card'}>,
#         <AxesSubplot:title={'center':'is_active_member'}>],
#        [<AxesSubplot:title={'center':'estimated_salary'}>,
#         <AxesSubplot:title={'center':'exited'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### 4.1.3 Categorical Variable

# %%
# geography
plt.subplot( 2, 2, 1 )
sns.countplot( df4['geography'] )

plt.subplot( 2, 2, 2 )
sns.kdeplot( df4[df4['geography'] == 'France']['exited'], label='France', shade=True )
sns.kdeplot( df4[df4['geography'] == 'Spain']['exited'], label='Spain', shade=True )
sns.kdeplot( df4[df4['geography'] == 'Germany']['exited'], label='Germany', shade=True )

# gender
plt.subplot( 2, 2, 3 )
sns.countplot( df4['gender'] )

plt.subplot( 2, 2, 4 )
sns.kdeplot( df4[df4['gender'] == 'Female']['exited'], label='Female', shade=True )
sns.kdeplot( df4[df4['gender'] == 'Male']['exited'], label='Male', shade=True )
# Out:
# /Users/luishmq/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/luishmq/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='exited', ylabel='Density'>

# %% [markdown]
# ## 4.2 Análise Bivariada

# %% [markdown]
# ### H1.A atividade do cliente influencia em possível churn?

# %%
aux1 = df4[['is_active_member', 'exited']].groupby( 'is_active_member' ).sum().reset_index()
plt.subplot( 1, 2, 1 )
sns.regplot( x ='is_active_member', y='exited', data=aux1 );

aux1 = df4[['is_active_member', 'exited']].groupby( 'is_active_member' ).sum().reset_index()
plt.subplot( 1, 2, 2 )
sns.barplot( x='is_active_member', y='exited', data=aux1 );

# %% [markdown]
# ### H2.A localidade do cliente influencia em possível churn?

# %%
plt.subplot( 1, 2, 1 )
aux1 = df4[['geography', 'exited']].groupby( 'geography' ).sum().reset_index()
sns.barplot( x='geography', y='exited', data=aux1 );

# %% [markdown]
# ### H3.A idade do cliente influencia em possível churn?

# %%
plt.subplot( 1, 2, 1 )
aux1 = df4[['age', 'exited']].groupby( 'age' ).sum().reset_index()
sns.barplot( x='age', y='exited', data=aux1 );

# %% [markdown]
# ### H4.A tenure do cliente influencia em possível churn?

# %%
plt.subplot( 1, 2, 1 )
aux1 = df4[['tenure', 'exited']].groupby( 'tenure' ).sum().reset_index()
sns.barplot( x='tenure', y='exited', data=aux1 );

# %% [markdown]
# ### H5.O fato do cliente possuir cartão de crédito influencia em possível churn?

# %%
plt.subplot( 1, 2, 1 )
aux1 = df4[['has_cr_card', 'exited']].groupby( 'has_cr_card' ).sum().reset_index()
sns.barplot( x='has_cr_card', y='exited', data=aux1 );

# %% [markdown]
# ### H6.O score do cliente influencia em possível churn?

# %%
plt.subplot( 1, 2, 1 )
aux1 = df4[['credit_score', 'exited']].groupby( 'credit_score' ).sum().reset_index()
sns.barplot( x='credit_score', y='exited', data=aux1 );

# %% [markdown]
# ### H7.O número de produtos comprados pelo cliente influencia em possível churn?

# %%
plt.subplot( 1, 2, 1 )
aux1 = df4[['num_of_products', 'exited']].groupby( 'num_of_products' ).sum().reset_index()
sns.barplot( x='num_of_products', y='exited', data=aux1 );

# %% [markdown]
# ## 4.3 Análise Multivariada

# %% [markdown]
# ### 4.3.1 Numerical Attributes

# %%
correlation = num_attributes.corr( method='pearson' )
sns.heatmap( correlation, annot=True );

# %% [markdown]
# ### 4.3.2 Categorical Attributes

# %%
# Selecionando somente Dados Categóricos
cat = df4.select_dtypes(include='object')

# Calcula Cramer V
a1 = cramer_v(cat['geography'], cat['geography'])
a2 = cramer_v(cat['geography'], cat['gender'])

a3 = cramer_v(cat['gender'], cat['geography'])
a4 = cramer_v(cat['gender'], cat['gender'])

# Dataset Final
df = pd.DataFrame({'geography': [a1, a2],
                   'gender': [a3, a4],
                  })
df = df.set_index(df.columns)

# Mapa de Calor para verificar a correlação entre as variáveis categóricas
sns.heatmap(df, annot=True);

# %% [markdown]
# # 5.0 Data Preparation

# %%
df5 = df4.copy()

# %% [markdown]
# ## 5.1 Normalização

# %% [markdown]
# ## 5.2 Rescaling

# %%
mms = MinMaxScaler()

# credit_score
df5['credit_score'] = mms.fit_transform( df5[['credit_score']].values )

# balance
df5['balance'] = mms.fit_transform(df5[['balance']].values )

# estimated_salary
df5['estimated_salary'] = mms.fit_transform( df5[['estimated_salary']].values )

# tenure
df5['tenure'] = mms.fit_transform( df5[['tenure']].values )

# age
df5['age'] = mms.fit_transform( df5[['age']].values )

# %% [markdown]
# ## 5.3 Transformação

# %% [markdown]
# ### 5.3.1 Encoding

# %%
# gender - Label Encoding
le = LabelEncoder()
df5['gender'] = le.fit_transform( df5['gender'] )

# geography - Ordinal Encoding
geography_dict = {'France': 1, 'Spain': 2, 'Germany': 3}
df5['geography'] = df5['geography'].map( geography_dict )

# %% [markdown]
# # 6.0 Feature Selection

# %%
df6 = df5.copy()

# %% [markdown]
# ## 6.1 Split dataframe into training and test dataset

# %%
# Sorting Data and Terget
target = df6.exited
data = df6.drop('exited', axis=1)

# Spliting Data
X_train, X_test, y_train, y_test = train_test_split(data, target, train_size=0.80, test_size=0.20, random_state=42, stratify=target)

print(f'Train Size: {X_train.shape[0]} ({(X_train.shape[0]/df6.shape[0])*100}%)')
print(f'Train Size: {X_test.shape[0]} ({(X_test.shape[0]/df6.shape[0])*100}%)')
# Out:
# Train Size: 8000 (80.0%)
# Train Size: 2000 (20.0%)

# %% [markdown]
# ## 6.2 Ranking Best Features

# %%
# # model definition
forest = en.ExtraTreesClassifier(n_estimators=250, random_state=42, n_jobs=-1)

x_train_n = X_train
y_train_n = y_train
forest.fit(x_train_n, y_train_n)

# Print the feature ranking
print('Feature ranking')
df = pd.DataFrame()
for i, j in zip(x_train_n.columns, forest.feature_importances_):
    aux = pd.DataFrame({'feature': i, 'importance': j},index=[0])
    df= pd.concat([df, aux], axis=0)

df = df.sort_values('importance',ascending=False)
df
# Out:
# Feature ranking
#             feature  importance
# 0               age    0.233761
# 0   num_of_products    0.144265
# 0      credit_score    0.131450
# 0           balance    0.130989
# 0  estimated_salary    0.130976
# 0            tenure    0.106120
# 0         geography    0.046620
# 0  is_active_member    0.035377
# 0       has_cr_card    0.023235
# 0            gender    0.017205

# %% [markdown]
# ## 6.3 Boruta as Feature Selector

# %%
# training and test dataset for Boruta
X_train_n = X_train.values
y_train_n = y_train.values.ravel()

# define RandomForestRegressor
rf = en.RandomForestClassifier( n_jobs=-1 )

# define Boruta
boruta = BorutaPy( rf, n_estimators='auto', verbose=2, random_state=42 ).fit(X_train_n, y_train_n )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 9
#       6 rf = en.RandomForestClassifier( n_jobs=-1 )
#       8 # define Boruta
# ----> 9 boruta = BorutaPy( rf, n_estimators='auto', verbose=2, random_state=42 ).fit(X_train_n, y_train_n )
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/boruta/boruta_py.py:201, in BorutaPy.fit(self, X, y)
#     188 def fit(self, X, y):
#     189     """
#     190     Fits the Boruta feature selection with the provided estimator.
#     191
#    (...)
#     198         The target values.
#     199     """
# --> 201     return self._fit(X, y)
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/boruta/boruta_py.py:260, in BorutaPy._fit(self, X, y)
#     255 _iter = 1
#     256 # holds the decision about each feature:
#     257 # 0  - default state = tentative in original code
#     258 # 1  - accepted in original code
#     259 # -1 - rejected in original code
# --> 260 dec_reg = np.zeros(n_feat, dtype=np.int)
#     261 # counts how many times a given feature was more important than
#     262 # the best of the shadow features
#     263 hit_reg = np.zeros(n_feat, dtype=np.int)
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/numpy/__init__.py:305, in __getattr__(attr)
#     300     warnings.warn(
#     301         f"In the future `np.{attr}` will be defined as the "
#     302         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     304 if attr in __former_attrs__:
# --> 305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
#     313 if attr == 'testing':
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# # 7.0 Machine Learning Model Selection

# %%
df7 = df6.copy()

# %% [markdown]
# ## 7.1 Linear Regression Model

# %%
# model
lr = LinearRegression().fit( X_train, y_train )

# prediction
yhat_lr = lr.predict( X_test )

# performance
lr_result = ml_error( 'Linear Regression', np.expm1( y_test ), np.expm1(yhat_lr ) )
lr_result
# Out:
#           Model Name       MAE          MAPE      RMSE
# 0  Linear Regression  0.438795  7.591638e+14  0.649419

# %%
f1_score(y_test, yhat_lr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 f1_score(y_test, yhat_lr)
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1136, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1001 def f1_score(
#    1002     y_true,
#    1003     y_pred,
#    (...)
#    1009     zero_division="warn",
#    1010 ):
#    1011     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1012
#    1013     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1134     array([0.66666667, 1.        , 0.66666667])
#    1135     """
# -> 1136     return fbeta_score(
#    1137         y_true,
#    1138         y_pred,
#    1139         beta=1,
#    1140         labels=labels,
#    1141         pos_label=pos_label,
#    1142         average=average,
#    1143         sample_weight=sample_weight,
#    1144         zero_division=zero_division,
#    1145     )
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1277, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1148 def fbeta_score(
#    1149     y_true,
#    1150     y_pred,
#    (...)
#    1157     zero_division="warn",
#    1158 ):
#    1159     """Compute the F-beta score.
#    1160
#    1161     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1274     array([0.71..., 0.        , 0.        ])
#    1275     """
# -> 1277     _, _, f, _ = precision_recall_fscore_support(
#    1278         y_true,
#    1279         y_pred,
#    1280         beta=beta,
#    1281         labels=labels,
#    1282         pos_label=pos_label,
#    1283         average=average,
#    1284         warn_for=("f-score",),
#    1285         sample_weight=sample_weight,
#    1286         zero_division=zero_division,
#    1287     )
#    1288     return f
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1563, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1561 if beta < 0:
#    1562     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1563 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1565 # Calculate tp_sum, pred_sum, true_sum ###
#    1566 samplewise = average == "samples"
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1364, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1361 if average not in average_options and average != "binary":
#    1362     raise ValueError("average has to be one of " + str(average_options))
# -> 1364 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1365 # Convert to Python primitive type to avoid NumPy type / Python str
#    1366 # comparison. See https://github.com/numpy/numpy/issues/6784
#    1367 present_labels = unique_labels(y_true, y_pred).tolist()
#
# File ~/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/sklearn/metrics/_classification.py:93, in _check_targets(y_true, y_pred)
#      90     y_type = {"multiclass"}
#      92 if len(y_type) > 1:
# ---> 93     raise ValueError(
#      94         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95             type_true, type_pred
#      96         )
#      97     )
#      99 # We can't have more than one value on y_type => The set is no more needed
#     100 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
# ## 7.2 Logistic Regression

# %%
# model
logr = LogisticRegression().fit( X_train, y_train )

# prediction
yhat_logr = logr.predict( X_test )

# performance
logr_result = ml_error( 'Logistic Regression', np.expm1( y_test ), np.expm1(yhat_logr ) )
logr_result
# Out:
#             Model Name       MAE          MAPE      RMSE
# 0  Logistic Regression  0.323896  1.625075e+14  0.746019

# %%
f1_score(y_test, yhat_logr)
# Out:
# 0.27639155470249516

# %% [markdown]
# ## 7.3 Random Forest Classifier

# %%
# model
X_train, y_train = make_classification(n_samples=1000, n_features=10,
                                        n_informative=2, n_redundant=0,
                                        random_state=42, shuffle=False)

rfc = RandomForestClassifier(max_depth=2, random_state=42)
rfc.fit(X_train, y_train)

# prediction
yhat_rfc = rfc.predict( X_test )

# performance
rfc_result = ml_error( 'Random Forest Classifier', np.expm1( y_test ), np.expm1(yhat_rfc ) )
rfc_result
# Out:
# /Users/luishmq/.pyenv/versions/3.8.13/envs/churn_prediction/lib/python3.8/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
#                  Model Name       MAE          MAPE      RMSE
# 0  Random Forest Classifier  1.368611  6.163678e+15  1.533512

# %%
accuracy_score(y_test, yhat_rfc)
f1_score(y_test, yhat_rfc)
# Out:
# 0.3381803074366431

# %% [markdown]
# ## 7.4 Extra Trees Classifier

# %%
# model definition
et_model = en.ExtraTreesClassifier(n_estimators = 100, n_jobs=-1, random_state=42)

# model fit
et_full_model = et_model.fit(X_train, y_train)

# model prediction
y_hat_et = et_model.predict(X_test)

etc_result = ml_error( 'Extra Trees Classifier', np.expm1( y_test ), np.expm1(y_hat_et ) )
etc_result
# Out:
#                Model Name       MAE          MAPE      RMSE
# 0  Extra Trees Classifier  0.249151  2.398921e+14  0.654302

# %%
accuracy_score(y_test, y_hat_et)
# Out:
# 0.855

# %% [markdown]
# ### 7.4.1 Extra Trees Cross Validation

# %% [markdown]
# ## 7.5 XGBoost Classifier

# %%
n = (y_train.shape[0] - y_train.sum())/y_train.sum()
# model definition
xgb_model = xgb.XGBClassifier(n_estimators = 600 ,scale_pos_weight=n )

# model fit
xgb_model.fit(X_train,y_train)

# model prediction
y_hat_xgb = xgb_model.predict(X_test)

xgb_result = ml_error( 'XGBoost Classifier', np.expm1( y_test ), np.expm1(y_hat_xgb ) )
xgb_result
# Out:
#            Model Name       MAE          MAPE      RMSE
# 0  XGBoost Classifier  0.286953  5.378225e+14  0.702187

# %%
accuracy_score(y_test, y_hat_xgb)
# Out:
# 0.833

# %% [markdown]
# # 8.0 Hyperparameter Fine Tuning
